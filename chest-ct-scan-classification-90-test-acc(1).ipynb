# %%
#https://www.kaggle.com/code/vinuthavikas/chest-cancer-ct-scan-detector/edit
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import tensorflow as tf
from tensorflow.keras.layers import Conv2D,Dense,MaxPooling2D,Flatten,BatchNormalization,Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.applications import VGG16
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.resnet import preprocess_input
import matplotlib.pyplot as plt
import cv2 as cv
# from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix,classification_report
# from keras.utils import to_categorical

import os

# %%
train_path_str = 'C:/Users/Vinutha/Downloads/archive (7)/Data/train'

# %%
val_path_str = 'C:/Users/Vinutha/Downloads/archive (7)/Data/valid'
test_path_str = 'C:/Users/Vinutha/Downloads/archive (7)/Data/test'

# %%
test_classes = os.listdir(test_path_str)

# %%
input_shape = (224,224,3)
num_classes = 4

trainGenertor = ImageDataGenerator(
    preprocessing_function = preprocess_input,
    rotation_range = 10,
    width_shift_range = 0.3,
    height_shift_range = 0.3,
    shear_range = 0.2,
    zoom_range = 0.1,
    horizontal_flip = True,
    vertical_flip = True,
    dtype = 'float32'
)
valGenertor = ImageDataGenerator(
    preprocessing_function = preprocess_input,
    dtype = 'float32'
)

testGenertor = ImageDataGenerator(
    preprocessing_function = preprocess_input,
    dtype = 'float32'
)

# %%
train_data = trainGenertor.flow_from_directory(
    train_path_str,
    target_size = (224,224),
    batch_size = 16,
    class_mode = 'categorical'
)

val_data = valGenertor.flow_from_directory(
    val_path_str,
    target_size = (224,224),
    batch_size = 16,
    class_mode = 'categorical'
)

test_data = testGenertor.flow_from_directory(
    test_path_str,
    target_size = (224,224),
    batch_size = 16,
    class_mode = 'categorical',
    shuffle = False
)
# Out:
# Found 613 images belonging to 4 classes.
# Found 72 images belonging to 4 classes.
# Found 315 images belonging to 4 classes.

# %%
VGG16_model = VGG16(
    include_top = False,
    weights="imagenet",
    input_shape = input_shape
)
for layer in VGG16_model.layers :
  layer.trainable = False

# %%
#from keras.src.metrics.confusion_metrics import activations
model = Sequential()
model.add(VGG16_model)
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))
model.add(Flatten())
model.add(Dense(1024,activation = 'relu'))
model.add(Dropout(0.3))
model.add(Dense(512,activation = 'relu'))
model.add(Dropout(0.3))
model.add(Dense(256,activation = 'relu'))
model.add(Dense(128,activation = 'relu'))
model.add(Dense(num_classes,activation = 'softmax'))
model.summary()

# %%
model.compile(
    optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy']
)
callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=5),
    tf.keras.callbacks.ModelCheckpoint('model.h5',save_best_only=True),
    tf.keras.callbacks.TensorBoard(log_dir='logs')
]

# %%
results = model.fit(train_data,validation_data=val_data,epochs=100,verbose = 1)
# Out:
# Epoch 1/100
# 39/39 [==============================] - 894s 23s/step - loss: 0.2320 - accuracy: 0.9217 - val_loss: 0.5099 - val_accuracy: 0.8472
# Epoch 2/100
# 39/39 [==============================] - 146s 4s/step - loss: 0.1804 - accuracy: 0.9299 - val_loss: 0.5434 - val_accuracy: 0.8333
# Epoch 3/100
# 39/39 [==============================] - 147s 4s/step - loss: 0.1159 - accuracy: 0.9527 - val_loss: 0.7434 - val_accuracy: 0.8333
# Epoch 4/100
# 39/39 [==============================] - 149s 4s/step - loss: 0.2078 - accuracy: 0.9315 - val_loss: 0.4855 - val_accuracy: 0.8750
# Epoch 5/100
# 39/39 [==============================] - 147s 4s/step - loss: 0.1796 - accuracy: 0.9347 - val_loss: 0.5703 - val_accuracy: 0.8611
# Epoch 6/100
# 39/39 [==============================] - 144s 4s/step - loss: 0.2351 - accuracy: 0.9250 - val_loss: 0.4070 - val_accuracy: 0.8750
# Epoch 7/100
# 39/39 [==============================] - 147s 4s/step - loss: 0.1887 - accuracy: 0.9413 - val_loss: 0.5200 - val_accuracy: 0.8611
# Epoch 8/100
# 39/39 [==============================] - 148s 4s/step - loss: 0.1756 - accuracy: 0.9413 - val_loss: 0.5159 - val_accuracy: 0.8472
# Epoch 9/100
# 39/39 [==============================] - 148s 4s/step - loss: 0.2081 - accuracy: 0.9347 - val_loss: 0.4403 - val_accuracy: 0.8750
# Epoch 10/100
# 39/39 [==============================] - 148s 4s/step - loss: 0.1661 - accuracy: 0.9315 - val_loss: 0.5496 - val_accuracy: 0.8472
# Epoch 11/100
# 39/39 [==============================] - 151s 4s/step - loss: 0.1435 - accuracy: 0.9347 - val_loss: 0.7396 - val_accuracy: 0.8472
# Epoch 12/100
# 39/39 [==============================] - 154s 4s/step - loss: 0.1717 - accuracy: 0.9445 - val_loss: 0.6975 - val_accuracy: 0.8472
# Epoch 13/100
# 39/39 [==============================] - 149s 4s/step - loss: 0.1610 - accuracy: 0.9445 - val_loss: 0.6014 - val_accuracy: 0.8472
# Epoch 14/100
# 39/39 [==============================] - 152s 4s/step - loss: 0.1582 - accuracy: 0.9299 - val_loss: 0.7060 - val_accuracy: 0.8611
# Epoch 15/100
# 39/39 [==============================] - 147s 4s/step - loss: 0.1274 - accuracy: 0.9462 - val_loss: 0.7412 - val_accuracy: 0.8611
# Epoch 16/100
# 39/39 [==============================] - 148s 4s/step - loss: 0.1647 - accuracy: 0.9462 - val_loss: 0.5597 - val_accuracy: 0.8611
# Epoch 17/100
# 39/39 [==============================] - 148s 4s/step - loss: 0.1565 - accuracy: 0.9429 - val_loss: 0.8722 - val_accuracy: 0.8750
# Epoch 18/100
# 39/39 [==============================] - 148s 4s/step - loss: 0.1616 - accuracy: 0.9429 - val_loss: 0.7259 - val_accuracy: 0.8611
# Epoch 19/100
# 39/39 [==============================] - 149s 4s/step - loss: 0.1828 - accuracy: 0.9380 - val_loss: 0.6114 - val_accuracy: 0.8889
# Epoch 20/100
# 39/39 [==============================] - 148s 4s/step - loss: 0.1586 - accuracy: 0.9380 - val_loss: 0.7228 - val_accuracy: 0.8611
# Epoch 21/100
# 39/39 [==============================] - 149s 4s/step - loss: 0.1430 - accuracy: 0.9462 - val_loss: 0.7335 - val_accuracy: 0.8472
# Epoch 22/100
# 39/39 [==============================] - 148s 4s/step - loss: 0.1581 - accuracy: 0.9347 - val_loss: 0.6142 - val_accuracy: 0.8333
# Epoch 23/100
# 39/39 [==============================] - 149s 4s/step - loss: 0.1838 - accuracy: 0.9217 - val_loss: 0.6379 - val_accuracy: 0.8611
# Epoch 24/100
# 39/39 [==============================] - 149s 4s/step - loss: 0.2092 - accuracy: 0.9201 - val_loss: 0.5256 - val_accuracy: 0.8611
# Epoch 25/100
# 39/39 [==============================] - 153s 4s/step - loss: 0.1695 - accuracy: 0.9511 - val_loss: 0.7469 - val_accuracy: 0.8750
# Epoch 26/100
# 39/39 [==============================] - 151s 4s/step - loss: 0.1869 - accuracy: 0.9462 - val_loss: 0.7251 - val_accuracy: 0.8750
# Epoch 27/100
# 39/39 [==============================] - 157s 4s/step - loss: 0.1638 - accuracy: 0.9462 - val_loss: 0.7806 - val_accuracy: 0.8750
# Epoch 28/100
# 39/39 [==============================] - 147s 4s/step - loss: 0.1465 - accuracy: 0.9478 - val_loss: 0.7435 - val_accuracy: 0.8611
# Epoch 29/100
# 39/39 [==============================] - 156s 4s/step - loss: 0.1467 - accuracy: 0.9511 - val_loss: 1.3304 - val_accuracy: 0.8194
# Epoch 30/100
# 39/39 [==============================] - 150s 4s/step - loss: 0.1460 - accuracy: 0.9543 - val_loss: 1.2380 - val_accuracy: 0.8333
# Epoch 31/100
# 39/39 [==============================] - 159s 4s/step - loss: 0.1798 - accuracy: 0.9380 - val_loss: 0.8276 - val_accuracy: 0.8889
# Epoch 32/100
# 39/39 [==============================] - 152s 4s/step - loss: 0.1573 - accuracy: 0.9380 - val_loss: 0.9788 - val_accuracy: 0.9028
# Epoch 33/100
# 39/39 [==============================] - 149s 4s/step - loss: 0.1450 - accuracy: 0.9478 - val_loss: 0.9868 - val_accuracy: 0.8750
# Epoch 34/100
# 39/39 [==============================] - 144s 4s/step - loss: 0.1957 - accuracy: 0.9380 - val_loss: 0.7765 - val_accuracy: 0.8750
# Epoch 35/100
# 39/39 [==============================] - 128s 3s/step - loss: 0.1629 - accuracy: 0.9445 - val_loss: 0.7429 - val_accuracy: 0.8750
# Epoch 36/100
# 39/39 [==============================] - 130s 3s/step - loss: 0.1878 - accuracy: 0.9315 - val_loss: 0.6440 - val_accuracy: 0.9028
# Epoch 37/100
# 39/39 [==============================] - 128s 3s/step - loss: 0.1570 - accuracy: 0.9511 - val_loss: 0.6927 - val_accuracy: 0.9167
# Epoch 38/100
# 39/39 [==============================] - 128s 3s/step - loss: 0.1451 - accuracy: 0.9543 - val_loss: 0.5502 - val_accuracy: 0.9028
# Epoch 39/100
# 39/39 [==============================] - 318s 8s/step - loss: 0.1637 - accuracy: 0.9478 - val_loss: 0.5320 - val_accuracy: 0.8611
# Epoch 40/100
# 39/39 [==============================] - 134s 3s/step - loss: 0.1565 - accuracy: 0.9413 - val_loss: 0.5213 - val_accuracy: 0.9167
# Epoch 41/100
# 10/39 [======>.......................] - ETA: 1:28 - loss: 0.1870 - accuracy: 0.9463

# %%
loss, acc = model.evaluate(test_data,verbose = 1)

# %%
import seaborn as sns
predictions_prob = model.predict(test_data)
predictions = np.argmax(predictions_prob , axis = 1)
true_label = test_data.classes
report = classification_report(true_label,predictions)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.79      0.86       120
#            1       0.71      0.94      0.81        51
#            2       1.00      0.94      0.97        54
#            3       0.81      0.84      0.83        90
#
#     accuracy                           0.86       315
#    macro avg       0.86      0.88      0.87       315
# weighted avg       0.87      0.86      0.86       315

# %%
conf_mat = confusion_matrix(true_label,predictions)
sns.heatmap(conf_mat ,fmt='g',annot = True , cmap='Blues' , xticklabels=test_classes , yticklabels = test_classes,)
plt.xlabel('Predictions')
plt.ylabel('True label')
plt.title('Confusion Matrix')
plt.xticks(rotation = 45)
plt.show()

# %%
res = results.history
train_acc = res['accuracy']
val_accuracy = res['val_accuracy']
epochs = range(1, len(train_acc) + 1)

line1 = plt.plot(epochs, val_accuracy, label = 'Validation/Test Accuracy')
line2 = plt.plot(epochs, train_acc, label = 'Training Accuracy')

plt.setp(line1, linewidth = 1.8, marker = 'o', markersize = 6.5)
plt.setp(line2, linewidth = 1.8, marker = 's', markersize = 5)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.show()

# %%
res = results.history
train_loss = res['loss']
val_loss = res['val_loss']
epochs = range(1, len(train_loss) + 1)

line1 = plt.plot(epochs, val_loss, label = 'Validation/Test Loss')
line2 = plt.plot(epochs, train_loss, label = 'Training Loss')

plt.setp(line1, linewidth = 1.8, marker = 'o', markersize = 6.5)
plt.setp(line2, linewidth = 1.8, marker = 's', markersize = 5)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.show()
